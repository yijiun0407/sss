# %%
chrome = 'C:/Users/yijiun0407/Downloads/chromedriver_win32/chromedriver.exe'

# %%
from selenium import webdriver

# %%
driver = webdriver.Chrome(chrome)

# %%
driver.get('https://www.google.com.tw/')

# %%
search_box = driver.find_element_by_xpath('//*[@id="tsf"]/div[2]/div[1]/div[1]/div/div[2]/input')

# %%
search_box.send_keys('weather')

# %%
search_box.submit()

# %%
driver.get('https://www.google.com.tw/')

# %%
good_luck = driver.find_element_by_xpath('//*[@id="tsf"]/div[2]/div[1]/div[3]/center/input[2]')

# %%
good_luck.click()

# %%
content = driver.page_source

# %%
content
# Out:
# '<html lang="zh_TW"><head>\n    \n    <title>Google Doodle 作品</title>\n    \n    \n      <link rel="stylesheet" href="/doodles/static/styles.css" type="text/css">\n    \n    \n    \n    <meta name="google-site-verification" content="dr6LvfGy2v_-FnxOJz4HFlNKNR_VpaN0xCA_T8RXAfk">\n    \n    <meta http-equiv="X-UA-Compatible" content="IE=edge">\n    \n    \n      \n      <meta property="og:description" content="前往 google.com/doodles 瀏覽更多 Doodle 圖案！">\n      <meta property="description" content="前往 google.com/doodles 瀏覽更多 Doodle 圖案！">\n      <meta property="twitter:description" content="前往 google.com/doodles 瀏覽更多 Doodle 圖案！">\n    \n    \n<script type="text/javascript" async="" src="https://ssl.google-analytics.com/ga.js"></script><script type="text/javascript">\n  var _gaq = _gaq || [];\n  _gaq.push([\'_setAccount\', \'UA-25773869-2\']);\n  _gaq.push([\'_setCookiePath\', \'/doodles\']);\n  _gaq.push([\'_trackPageview\']);\n  (function() {\n     var ga = document.createElement(\'script\'
# ...

# %%
from bs4 import BeautifulSoup as bs

# %%
google = bs(content, 'html.parser')

# %%
google
# Out:
# <html lang="zh_TW"><head>
# <title>Google Doodle 作品</title>
# <link href="/doodles/static/styles.css" rel="stylesheet" type="text/css"/>
# <meta content="dr6LvfGy2v_-FnxOJz4HFlNKNR_VpaN0xCA_T8RXAfk" name="google-site-verification"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="前往 google.com/doodles 瀏覽更多 Doodle 圖案！" property="og:description"/>
# <meta content="前往 google.com/doodles 瀏覽更多 Doodle 圖案！" property="description"/>
# <meta content="前往 google.com/doodles 瀏覽更多 Doodle 圖案！" property="twitter:description"/>
# <script async="" src="https://ssl.google-analytics.com/ga.js" type="text/javascript"></script><script type="text/javascript">
#   var _gaq = _gaq || [];
#   _gaq.push(['_setAccount', 'UA-25773869-2']);
#   _gaq.push(['_setCookiePath', '/doodles']);
#   _gaq.push(['_trackPageview']);
#   (function() {
#      var ga = document.createElement('script');
#      ga.type = 'text/javascript'; ga.async = true;
# ...

# %%
print (google.prettify())
# Out:
# <html lang="zh_TW">
#  <head>
#   <title>
#    Google Doodle 作品
#   </title>
#   <link href="/doodles/static/styles.css" rel="stylesheet" type="text/css"/>
#   <meta content="dr6LvfGy2v_-FnxOJz4HFlNKNR_VpaN0xCA_T8RXAfk" name="google-site-verification"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="前往 google.com/doodles 瀏覽更多 Doodle 圖案！" property="og:description"/>
#   <meta content="前往 google.com/doodles 瀏覽更多 Doodle 圖案！" property="description"/>
#   <meta content="前往 google.com/doodles 瀏覽更多 Doodle 圖案！" property="twitter:description"/>
#   <script async="" src="https://ssl.google-analytics.com/ga.js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    var _gaq = _gaq || [];
#   _gaq.push(['_setAccount', 'UA-25773869-2']);
#   _gaq.push(['_setCookiePath', '/doodles']);
#   _gaq.push(['_trackPageview']);
#   (function() {
#      var ga = document.createElement('script');
#      ga.type = 'text/javascript'; ga.async = true;
# ...
