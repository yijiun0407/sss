# %%
import pandas as pd

# %%
print (pd.__version__)
# Out:
# 0.23.4

# %%
# using ! command mode to execute command
# !dir
# Out:
#  磁碟區 C 中的磁碟是 Acer
#  磁碟區序號:  7894-6D86
#
#  C:\Users\yijiun0407\Documents\GitHub\sss 的目錄
#
# 2019/08/13  下午 06:37    <DIR>          .
# 2019/08/13  下午 06:37    <DIR>          ..
# 2019/08/13  下午 06:35    <DIR>          .ipynb_checkpoints
# 2019/05/07  下午 08:27            18,194 190507.ipynb
# 2019/05/14  下午 07:59            22,077 190514.ipynb
# 2019/05/21  下午 07:56            29,324 190521.ipynb
# 2019/06/18  下午 07:44             4,373 190618.ipynb
# 2019/06/25  下午 08:12            10,080 190625.ipynb
# 2019/07/30  下午 07:51            52,460 190730.ipynb
# 2019/04/02  下午 08:28             1,754 20190402_python101_note.md
# 2019/04/02  下午 08:28             1,754 20190402_python101_note.py
# 2019/04/16  下午 07:07            26,587 20190409_note.ipynb
# 2019/04/16  下午 08:04            10,407 20190416.ipynb
# 2019/04/30  下午 08:13             8,165 20190430-1.ipynb
# 2019/04/30  下午 06:42             7,363 20190430.ipynb
# 2019/06/18  下午 06:24               183 20190618_data.txt
# ...

# %%
#list all packages's name & version
# !pip list
# Out:
# Package                            Version
# ---------------------------------- ----------
# alabaster                          0.7.12
# anaconda-client                    1.7.2
# anaconda-navigator                 1.9.6
# anaconda-project                   0.8.2
# asn1crypto                         0.24.0
# astroid                            2.1.0
# astropy                            3.1
# atomicwrites                       1.2.1
# attrs                              18.2.0
# Babel                              2.6.0
# backcall                           0.1.0
# backports.os                       0.1.1
# backports.shutil-get-terminal-size 1.0.0
# beautifulsoup4                     4.6.3
# bitarray                           0.8.3
# bkcharts                           0.2
# blaze                              0.11.3
# bleach                             3.0.2
# blessings                          1.7
# bokeh                              1.0.2
# boto                               2.49.0
# ...

# %%
#pandas basic 
#read data using pandas

sheet0=pd.read_excel('20190806_python_club_pandas_demo_data.xlsx',sheet_name=0)
sheet1=pd.read_excel('20190806_python_club_pandas_demo_data.xlsx',sheet_name=1)

# %%
sheet0.head()
# Out:
#                     run.name sample.name     type   gene    chr     start  \
# 0  Proton_B_48_IonXpress_014      B00246  Serous   PGAP3  chr17  37829249
# 1  Proton_B_48_IonXpress_014      B00246  Serous    CRKL  chr22  21272220
# 2  Proton_B_48_IonXpress_014      B00246  Serous   BUB1B  chr15  40453332
# 3  Proton_B_48_IonXpress_014      B00246  Serous   STK11  chr19   1206845
# 4  Proton_B_48_IonXpress_014      B00246  Serous    MEN1  chr11  64571750
#
#         end tumor purity copy.number copy*purity       ...         \
# 0  37844307        30.0%           2           2       ...
# 1  21304221          NaN           2           2       ...
# 2  40512974        30.0%         1.5         1.5       ...
# 3   1223244        30.0%           2           2       ...
# 4  64577547        30.0%           3           3       ...
#
#                                 comments  amplicon.total amplicon.final  \
# 0    p-value_correction=0.64177792041869              15             12
# ...

# %%
sheet1.head()
# Out:
#                     run.name sample.name        type    tumor purity
# 0  Proton_B_80_IonXpress_055      B00278  Clear cell  39.3516930545%
# 1  Proton_B_60_IonXpress_011      B00281  Clear cell  71.1469043699%
# 2  Proton_B_60_IonXpress_012      B00282  Clear cell  45.2759315905%
# 3  Proton_B_80_IonXpress_056      B00283  Clear cell  34.9154300663%
# 4  Proton_B_60_IonXpress_013      B00284  Clear cell  50.7430962998%

# %%
coffee = pd.read_clipboard()#複製的範圍

# %%
coffee
# Out:
#                     run.name sample.name        type
# 0  Proton_B_80_IonXpress_055      B00278  Clear cell
# 1  Proton_B_60_IonXpress_011      B00281  Clear cell
# 2  Proton_B_60_IonXpress_012      B00282  Clear cell
# 3  Proton_B_80_IonXpress_056      B00283  Clear cell
# 4  Proton_B_60_IonXpress_013      B00284  Clear cell
# 5  Proton_B_61_IonXpress_014      B00285  Clear cell

# %%
txt_file = pd.read_csv('20190618_data.txt',sep='\t') #txt 是 tab 分隔

# %%
txt_file
# Out:
#    Proton_A_20190421_IonXpress_012_F00129_CNV.txt
# 0  Proton_B_20190512_IonXpress_037_F00876_CNV.txt
# 1    S5PR_A_20190311_IonXpress_055_E00675_VCF.txt
# 2    S5PR_B_20190219_IonXpress_085_E00564_VCF.txt

# %%
txt_file1 = pd.read_table('20190618_data.txt')

# %%
txt_file1
# Out:
#    Proton_A_20190421_IonXpress_012_F00129_CNV.txt
# 0  Proton_B_20190512_IonXpress_037_F00876_CNV.txt
# 1    S5PR_A_20190311_IonXpress_055_E00675_VCF.txt
# 2    S5PR_B_20190219_IonXpress_085_E00564_VCF.txt

# %%
coffee.shape
# Out:
# (6, 3)

# %%
coffee.columns
# Out:
# Index(['run.name', 'sample.name', 'type'], dtype='object')

# %%
coffee.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
coffee
# Out:
#                     run.name sample.name        type
# 0  Proton_B_80_IonXpress_055      B00278  Clear cell
# 1  Proton_B_60_IonXpress_011      B00281  Clear cell
# 2  Proton_B_60_IonXpress_012      B00282  Clear cell
# 3  Proton_B_80_IonXpress_056      B00283  Clear cell
# 4  Proton_B_60_IonXpress_013      B00284  Clear cell
# 5  Proton_B_61_IonXpress_014      B00285  Clear cell

# %%
coffee.set_index('run.name') #暫時
# Out:
#                           sample.name        type
# run.name
# Proton_B_80_IonXpress_055      B00278  Clear cell
# Proton_B_60_IonXpress_011      B00281  Clear cell
# Proton_B_60_IonXpress_012      B00282  Clear cell
# Proton_B_80_IonXpress_056      B00283  Clear cell
# Proton_B_60_IonXpress_013      B00284  Clear cell
# Proton_B_61_IonXpress_014      B00285  Clear cell

# %%
coffee
# Out:
#                     run.name sample.name        type
# 0  Proton_B_80_IonXpress_055      B00278  Clear cell
# 1  Proton_B_60_IonXpress_011      B00281  Clear cell
# 2  Proton_B_60_IonXpress_012      B00282  Clear cell
# 3  Proton_B_80_IonXpress_056      B00283  Clear cell
# 4  Proton_B_60_IonXpress_013      B00284  Clear cell
# 5  Proton_B_61_IonXpress_014      B00285  Clear cell

# %%
coffee.set_index('run.name',inplace=True) #真的

# %%
coffee
# Out:
#                           sample.name        type
# run.name
# Proton_B_80_IonXpress_055      B00278  Clear cell
# Proton_B_60_IonXpress_011      B00281  Clear cell
# Proton_B_60_IonXpress_012      B00282  Clear cell
# Proton_B_80_IonXpress_056      B00283  Clear cell
# Proton_B_60_IonXpress_013      B00284  Clear cell
# Proton_B_61_IonXpress_014      B00285  Clear cell

# %%
coffee.reset_index()
# Out:
#                     run.name sample.name        type
# 0  Proton_B_80_IonXpress_055      B00278  Clear cell
# 1  Proton_B_60_IonXpress_011      B00281  Clear cell
# 2  Proton_B_60_IonXpress_012      B00282  Clear cell
# 3  Proton_B_80_IonXpress_056      B00283  Clear cell
# 4  Proton_B_60_IonXpress_013      B00284  Clear cell
# 5  Proton_B_61_IonXpress_014      B00285  Clear cell

# %%
coffee.reset_index(inplace=True)

# %%
coffee.sort_values(['run.name','sample.name'],ascending=False)
# Out:
#                     run.name sample.name        type
# 3  Proton_B_80_IonXpress_056      B00283  Clear cell
# 0  Proton_B_80_IonXpress_055      B00278  Clear cell
# 5  Proton_B_61_IonXpress_014      B00285  Clear cell
# 4  Proton_B_60_IonXpress_013      B00284  Clear cell
# 2  Proton_B_60_IonXpress_012      B00282  Clear cell
# 1  Proton_B_60_IonXpress_011      B00281  Clear cell

# %%
coffee.loc[:,-1:]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-f6f9650b9aad> in <module>
# ----> 1 coffee.loc[:,-1:]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1470             except (KeyError, IndexError):
#    1471                 pass
# -> 1472             return self._getitem_tuple(key)
#    1473         else:
#    1474             # we by definition only have the 0th axis
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#     888                 continue
#     889
# --> 890             retval = getattr(retval, self.name)._getitem_axis(key, axis=i)
#     891
#     892         return retval
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1864         if isinstance(key, slice):
#    1865             self._validate_key(key, axis)
# ...

# %%
coffee1 = pd.read_clipboard(sep='\t')

# %%
coffee1
# Out:
#                        烘培進度 name item price 1包(半磅) 總價
# 0       已處理 Yi-Ting 巴拿馬 波奎特山谷 凱薩路易斯日曬 卡度艾種 450 1包 450
# 1        已處理 Yi-Ting 衣索比亞【水洗】耶珈雪啡  果丁丁村 G1 350 1包 350
# 2   已處理 Yi-Wei 衣索比亞  (日曬) 耶加雪啡  果丁丁  (NEW) 380 1包 380
# 3     已處理 cgh2 中美洲 哥斯大黎加 寶藏莊園 黑蜜  Catuai 種 350 1包 350
# 4     已處理 cgh2 衣索比亞  (日曬) 耶加雪啡  果丁丁  (NEW) 380 1包 380
# 5    已處理 Doris 中美洲 哥斯大黎加 寶藏莊園 黑蜜  Catuai 種 350 1包 350
# 6             已處理 Lily 咖啡掛耳包    盒裝 10包 250 250 1包 250
# 7     已處理 Lily 衣索比亞  (日曬) 耶加雪啡  果丁丁  (NEW) 380 1包 380
# 8    已處理 Anson 衣索比亞  (日曬) 耶加雪啡  果丁丁  (NEW) 380 1包 380
# 9       已處理 Ab 衣索比亞  (日曬) 耶加雪啡  果丁丁  (NEW) 380 1包 380
# 10      已處理 Ab 中美洲 哥斯大黎加 寶藏莊園 黑蜜  Catuai 種 350 1包 350
# 11   已處理 Kowen 衣索比亞  (日曬) 耶加雪啡  果丁丁  (NEW) 380 1包 380
# 12      已處理 YJ 衣索比亞  (日曬) 耶加雪啡  果丁丁  (NEW) 380 1包 380
# 13                            已處理 JT 綜合咖啡豆 350 2磅 700

# %%
coffee2 = pd.read_table('cli_demo.txt')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-41-fb6ade6020ea> in <module>
# ----> 1 coffee2 = pd.read_table('cli_demo.txt')
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
#     676                     skip_blank_lines=skip_blank_lines)
#     677
# ...

# %%
coffee3 = pd.read_clipboard()

# %%
coffee3
# Out:
#    烘培進度     name                         item  price 1包(半磅)   總價
# 0   已處理  Yi-Ting       巴拿馬 波奎特山谷 凱薩路易斯日曬 卡度艾種    450     1包  450
# 1   已處理  Yi-Ting        衣索比亞【水洗】耶珈雪啡  果丁丁村 G1    350     1包  350
# 2   已處理   Yi-Wei  衣索比亞? (日曬) 耶加雪啡? 果丁丁 ?(NEW)    380     1包  380
# 3   已處理     cgh2  中美洲 哥斯大黎加 寶藏莊園 黑蜜  Catuai 種    350     1包  350
# 4   已處理     cgh2  衣索比亞? (日曬) 耶加雪啡? 果丁丁 ?(NEW)    380     1包  380
# 5   已處理    Doris  中美洲 哥斯大黎加 寶藏莊園 黑蜜  Catuai 種    350     1包  350
# 6   已處理     Lily          咖啡掛耳包    盒裝 10包 250    250     1包  250
# 7   已處理     Lily  衣索比亞? (日曬) 耶加雪啡? 果丁丁 ?(NEW)    380     1包  380
# 8   已處理    Anson  衣索比亞? (日曬) 耶加雪啡? 果丁丁 ?(NEW)    380     1包  380
# 9   已處理       Ab  衣索比亞? (日曬) 耶加雪啡? 果丁丁 ?(NEW)    380     1包  380
# 10  已處理       Ab  中美洲 哥斯大黎加 寶藏莊園 黑蜜  Catuai 種    350     1包  350
# 11  已處理    Kowen  衣索比亞? (日曬) 耶加雪啡? 果丁丁 ?(NEW)    380     1包  380
# 12  已處理       YJ  衣索比亞? (日曬) 耶加雪啡? 果丁丁 ?(NEW)    380     1包  380
# ...

# %%
coffee3.dtypes
# Out:
# 烘培進度      object
# name      object
# item      object
# price      int64
# 1包(半磅)    object
# 總價         int64
# dtype: object

# %%
coffee3.loc[coffee3['price']>350, :]
# Out:
#    烘培進度     name                         item  price 1包(半磅)   總價
# 0   已處理  Yi-Ting       巴拿馬 波奎特山谷 凱薩路易斯日曬 卡度艾種    450     1包  450
# 2   已處理   Yi-Wei  衣索比亞? (日曬) 耶加雪啡? 果丁丁 ?(NEW)    380     1包  380
# 4   已處理     cgh2  衣索比亞? (日曬) 耶加雪啡? 果丁丁 ?(NEW)    380     1包  380
# 7   已處理     Lily  衣索比亞? (日曬) 耶加雪啡? 果丁丁 ?(NEW)    380     1包  380
# 8   已處理    Anson  衣索比亞? (日曬) 耶加雪啡? 果丁丁 ?(NEW)    380     1包  380
# 9   已處理       Ab  衣索比亞? (日曬) 耶加雪啡? 果丁丁 ?(NEW)    380     1包  380
# 11  已處理    Kowen  衣索比亞? (日曬) 耶加雪啡? 果丁丁 ?(NEW)    380     1包  380
# 12  已處理       YJ  衣索比亞? (日曬) 耶加雪啡? 果丁丁 ?(NEW)    380     1包  380

# %%
coffee3.loc[(coffee3['price']>350 )&(coffee3['name'] =='cgh2'), :]
# Out:
#   烘培進度  name                         item  price 1包(半磅)   總價
# 4  已處理  cgh2  衣索比亞? (日曬) 耶加雪啡? 果丁丁 ?(NEW)    380     1包  380

# %%
coffee3.loc[coffee3['item'].str.contains('NEW'), : ]
# Out:
#    烘培進度    name                         item  price 1包(半磅)   總價
# 2   已處理  Yi-Wei  衣索比亞? (日曬) 耶加雪啡? 果丁丁 ?(NEW)    380     1包  380
# 4   已處理    cgh2  衣索比亞? (日曬) 耶加雪啡? 果丁丁 ?(NEW)    380     1包  380
# 7   已處理    Lily  衣索比亞? (日曬) 耶加雪啡? 果丁丁 ?(NEW)    380     1包  380
# 8   已處理   Anson  衣索比亞? (日曬) 耶加雪啡? 果丁丁 ?(NEW)    380     1包  380
# 9   已處理      Ab  衣索比亞? (日曬) 耶加雪啡? 果丁丁 ?(NEW)    380     1包  380
# 11  已處理   Kowen  衣索比亞? (日曬) 耶加雪啡? 果丁丁 ?(NEW)    380     1包  380
# 12  已處理      YJ  衣索比亞? (日曬) 耶加雪啡? 果丁丁 ?(NEW)    380     1包  380

# %%
coffee3
# Out:
#    烘培進度     name                         item  price 1包(半磅)   總價
# 0   已處理  Yi-Ting       巴拿馬 波奎特山谷 凱薩路易斯日曬 卡度艾種    450     1包  450
# 1   已處理  Yi-Ting        衣索比亞【水洗】耶珈雪啡  果丁丁村 G1    350     1包  350
# 2   已處理   Yi-Wei  衣索比亞? (日曬) 耶加雪啡? 果丁丁 ?(NEW)    380     1包  380
# 3   已處理     cgh2  中美洲 哥斯大黎加 寶藏莊園 黑蜜  Catuai 種    350     1包  350
# 4   已處理     cgh2  衣索比亞? (日曬) 耶加雪啡? 果丁丁 ?(NEW)    380     1包  380
# 5   已處理    Doris  中美洲 哥斯大黎加 寶藏莊園 黑蜜  Catuai 種    350     1包  350
# 6   已處理     Lily          咖啡掛耳包    盒裝 10包 250    250     1包  250
# 7   已處理     Lily  衣索比亞? (日曬) 耶加雪啡? 果丁丁 ?(NEW)    380     1包  380
# 8   已處理    Anson  衣索比亞? (日曬) 耶加雪啡? 果丁丁 ?(NEW)    380     1包  380
# 9   已處理       Ab  衣索比亞? (日曬) 耶加雪啡? 果丁丁 ?(NEW)    380     1包  380
# 10  已處理       Ab  中美洲 哥斯大黎加 寶藏莊園 黑蜜  Catuai 種    350     1包  350
# 11  已處理    Kowen  衣索比亞? (日曬) 耶加雪啡? 果丁丁 ?(NEW)    380     1包  380
# 12  已處理       YJ  衣索比亞? (日曬) 耶加雪啡? 果丁丁 ?(NEW)    380     1包  380
# ...

# %%
#s.str.extract(r'([ab])(\d)')
coffee3['number'] = coffee3['1包(半磅)'].str.extract(r'([0-9])')
coffee3['unit'] = coffee3['1包(半磅)'].str.extract(r'([^0-9])')

# %%
coffee3
# Out:
#    烘培進度     name                         item  price 1包(半磅)   總價 number unit
# 0   已處理  Yi-Ting       巴拿馬 波奎特山谷 凱薩路易斯日曬 卡度艾種    450     1包  450      1    包
# 1   已處理  Yi-Ting        衣索比亞【水洗】耶珈雪啡  果丁丁村 G1    350     1包  350      1    包
# 2   已處理   Yi-Wei  衣索比亞? (日曬) 耶加雪啡? 果丁丁 ?(NEW)    380     1包  380      1    包
# 3   已處理     cgh2  中美洲 哥斯大黎加 寶藏莊園 黑蜜  Catuai 種    350     1包  350      1    包
# 4   已處理     cgh2  衣索比亞? (日曬) 耶加雪啡? 果丁丁 ?(NEW)    380     1包  380      1    包
# 5   已處理    Doris  中美洲 哥斯大黎加 寶藏莊園 黑蜜  Catuai 種    350     1包  350      1    包
# 6   已處理     Lily          咖啡掛耳包    盒裝 10包 250    250     1包  250      1    包
# 7   已處理     Lily  衣索比亞? (日曬) 耶加雪啡? 果丁丁 ?(NEW)    380     1包  380      1    包
# 8   已處理    Anson  衣索比亞? (日曬) 耶加雪啡? 果丁丁 ?(NEW)    380     1包  380      1    包
# 9   已處理       Ab  衣索比亞? (日曬) 耶加雪啡? 果丁丁 ?(NEW)    380     1包  380      1    包
# 10  已處理       Ab  中美洲 哥斯大黎加 寶藏莊園 黑蜜  Catuai 種    350     1包  350      1    包
# ...

# %%
coffee3['weird'] = coffee3['name'] + "_"+ coffee3['item']+ "_"+ coffee3['unit']

# %%
coffee3
# Out:
#    烘培進度     name                         item  price 1包(半磅)   總價 number unit  \
# 0   已處理  Yi-Ting       巴拿馬 波奎特山谷 凱薩路易斯日曬 卡度艾種    450     1包  450      1    包
# 1   已處理  Yi-Ting        衣索比亞【水洗】耶珈雪啡  果丁丁村 G1    350     1包  350      1    包
# 2   已處理   Yi-Wei  衣索比亞? (日曬) 耶加雪啡? 果丁丁 ?(NEW)    380     1包  380      1    包
# 3   已處理     cgh2  中美洲 哥斯大黎加 寶藏莊園 黑蜜  Catuai 種    350     1包  350      1    包
# 4   已處理     cgh2  衣索比亞? (日曬) 耶加雪啡? 果丁丁 ?(NEW)    380     1包  380      1    包
# 5   已處理    Doris  中美洲 哥斯大黎加 寶藏莊園 黑蜜  Catuai 種    350     1包  350      1    包
# 6   已處理     Lily          咖啡掛耳包    盒裝 10包 250    250     1包  250      1    包
# 7   已處理     Lily  衣索比亞? (日曬) 耶加雪啡? 果丁丁 ?(NEW)    380     1包  380      1    包
# 8   已處理    Anson  衣索比亞? (日曬) 耶加雪啡? 果丁丁 ?(NEW)    380     1包  380      1    包
# 9   已處理       Ab  衣索比亞? (日曬) 耶加雪啡? 果丁丁 ?(NEW)    380     1包  380      1    包
# 10  已處理       Ab  中美洲 哥斯大黎加 寶藏莊園 黑蜜  Catuai 種    350     1包  350      1    包
# ...

# %%
coffee3[['name_1','coffee_name','unit_!']]= coffee3['weird'].str.split('_',expand = True)

# %%
coffee3
# Out:
#    烘培進度     name                         item  price 1包(半磅)   總價 number unit  \
# 0   已處理  Yi-Ting       巴拿馬 波奎特山谷 凱薩路易斯日曬 卡度艾種    450     1包  450      1    包
# 1   已處理  Yi-Ting        衣索比亞【水洗】耶珈雪啡  果丁丁村 G1    350     1包  350      1    包
# 2   已處理   Yi-Wei  衣索比亞? (日曬) 耶加雪啡? 果丁丁 ?(NEW)    380     1包  380      1    包
# 3   已處理     cgh2  中美洲 哥斯大黎加 寶藏莊園 黑蜜  Catuai 種    350     1包  350      1    包
# 4   已處理     cgh2  衣索比亞? (日曬) 耶加雪啡? 果丁丁 ?(NEW)    380     1包  380      1    包
# 5   已處理    Doris  中美洲 哥斯大黎加 寶藏莊園 黑蜜  Catuai 種    350     1包  350      1    包
# 6   已處理     Lily          咖啡掛耳包    盒裝 10包 250    250     1包  250      1    包
# 7   已處理     Lily  衣索比亞? (日曬) 耶加雪啡? 果丁丁 ?(NEW)    380     1包  380      1    包
# 8   已處理    Anson  衣索比亞? (日曬) 耶加雪啡? 果丁丁 ?(NEW)    380     1包  380      1    包
# 9   已處理       Ab  衣索比亞? (日曬) 耶加雪啡? 果丁丁 ?(NEW)    380     1包  380      1    包
# 10  已處理       Ab  中美洲 哥斯大黎加 寶藏莊園 黑蜜  Catuai 種    350     1包  350      1    包
# ...

# %%
coffee3.rename(columns={'name':'name_name','unit':'unit_unit'},inplace = True)

# %%
coffee3
# Out:
#    烘培進度 name_name                         item  price 1包(半磅)   總價 number  \
# 0   已處理   Yi-Ting       巴拿馬 波奎特山谷 凱薩路易斯日曬 卡度艾種    450     1包  450      1
# 1   已處理   Yi-Ting        衣索比亞【水洗】耶珈雪啡  果丁丁村 G1    350     1包  350      1
# 2   已處理    Yi-Wei  衣索比亞? (日曬) 耶加雪啡? 果丁丁 ?(NEW)    380     1包  380      1
# 3   已處理      cgh2  中美洲 哥斯大黎加 寶藏莊園 黑蜜  Catuai 種    350     1包  350      1
# 4   已處理      cgh2  衣索比亞? (日曬) 耶加雪啡? 果丁丁 ?(NEW)    380     1包  380      1
# 5   已處理     Doris  中美洲 哥斯大黎加 寶藏莊園 黑蜜  Catuai 種    350     1包  350      1
# 6   已處理      Lily          咖啡掛耳包    盒裝 10包 250    250     1包  250      1
# 7   已處理      Lily  衣索比亞? (日曬) 耶加雪啡? 果丁丁 ?(NEW)    380     1包  380      1
# 8   已處理     Anson  衣索比亞? (日曬) 耶加雪啡? 果丁丁 ?(NEW)    380     1包  380      1
# 9   已處理        Ab  衣索比亞? (日曬) 耶加雪啡? 果丁丁 ?(NEW)    380     1包  380      1
# 10  已處理        Ab  中美洲 哥斯大黎加 寶藏莊園 黑蜜  Catuai 種    350     1包  350      1
# 11  已處理     Kowen  衣索比亞? (日曬) 耶加雪啡? 果丁丁 ?(NEW)    380     1包  380      1
# ...

# %%
final = pd.concat('coffee','coffee3')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-72-92613f98ff23> in <module>
# ----> 1 final = pd.concat('coffee','coffee3')
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\concat.py in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     223                        keys=keys, levels=levels, names=names,
#     224                        verify_integrity=verify_integrity,
# --> 225                        copy=copy, sort=sort)
#     226     return op.get_result()
#     227
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\concat.py in __init__(self, objs, axis, join, join_axes, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     239             raise TypeError('first argument must be an iterable of pandas '
# ...
