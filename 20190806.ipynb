# %%
#Pandas basic

# %%
#list file in current directory

# %%
import os

# %%
#for loop
for _ in os.listdir('.'):
    if _.endswith('xlsx'):
        print(_)
# Out:
# 20190806_python_club_pandas_demo_data.xlsx

# %%
#list compregension
[_ for _ in os.listdir('.') if _.endswith('xlsx')]
# Out:
# ['20190806_python_club_pandas_demo_data.xlsx']

# %%
#read data using pandas

# %%
import pandas as pd

# %%
data_path = './20190806_python_club_pandas_demo_data.xlsx'

# %%
#step 1 read data
data_object = pd.read_excel(data_path)

# %%
type(data_object)
# Out:
# pandas.core.frame.DataFrame

# %%
data_object.head()
# Out:
#                     run.name sample.name     type   gene    chr     start  \
# 0  Proton_B_48_IonXpress_014      B00246  Serous   PGAP3  chr17  37829249
# 1  Proton_B_48_IonXpress_014      B00246  Serous    CRKL  chr22  21272220
# 2  Proton_B_48_IonXpress_014      B00246  Serous   BUB1B  chr15  40453332
# 3  Proton_B_48_IonXpress_014      B00246  Serous   STK11  chr19   1206845
# 4  Proton_B_48_IonXpress_014      B00246  Serous    MEN1  chr11  64571750
#
#         end tumor purity copy.number copy*purity       ...         \
# 0  37844307        30.0%           2           2       ...
# 1  21304221          NaN           2           2       ...
# 2  40512974        30.0%         1.5         1.5       ...
# 3   1223244        30.0%           2           2       ...
# 4  64577547        30.0%           3           3       ...
#
#                                 comments  amplicon.total amplicon.final  \
# 0    p-value_correction=0.64177792041869              15             12
# ...

# %%
data_object.tail()
# Out:
#                         run.name sample.name     type     gene    chr  \
# 39259  Proton_B_77_IonXpress_043      B00251  Serous      BAP1   chr3
# 39260  Proton_B_77_IonXpress_043      B00251  Serous      SDHB   chr1
# 39261  Proton_B_77_IonXpress_043      B00251  Serous      ATF1  chr12
# 39262  Proton_B_77_IonXpress_043      B00251  Serous      SDHD  chr11
# 39263  Proton_B_77_IonXpress_043      B00251  Serous   PRKAR1A  chr17
#
#            start        end    tumor purity copy.number copy*purity  \
# 39259   52436209   52443884             NaN           2           2
# 39260   17345298   17380566             NaN         1.5         1.5
# 39261   51173949   51213477  66.3812742265%         1.5         1.5
# 39262  111957588  111965599             NaN           2           2
# 39263   66511460   66526627             NaN         1.5         1.5
#
#             ...                                                  comments  \
# ...

# %%
data_object.head(10)#default first 5 row
# Out:
#                     run.name sample.name     type    gene    chr      start  \
# 0  Proton_B_48_IonXpress_014      B00246  Serous    PGAP3  chr17   37829249
# 1  Proton_B_48_IonXpress_014      B00246  Serous     CRKL  chr22   21272220
# 2  Proton_B_48_IonXpress_014      B00246  Serous    BUB1B  chr15   40453332
# 3  Proton_B_48_IonXpress_014      B00246  Serous    STK11  chr19    1206845
# 4  Proton_B_48_IonXpress_014      B00246  Serous     MEN1  chr11   64571750
# 5  Proton_B_48_IonXpress_014      B00246  Serous    USP9X   chrX   40982874
# 6  Proton_B_48_IonXpress_014      B00246  Serous    IL6ST   chr5   55236904
# 7  Proton_B_48_IonXpress_014      B00246  Serous     LIFR   chr5   38481676
# 8  Proton_B_48_IonXpress_014      B00246  Serous    CDC73   chr1  193091222
# 9  Proton_B_48_IonXpress_014      B00246  Serous   PIK3CA   chr3  178916622
#
#          end tumor purity copy.number copy*purity       ...         \
# 0   37844307        30.0%           2           2       ...
# ...

# %%
#read data using pen or with open  >>>>  but excel 無法用此方式

with open(data_path,'r') as rf:
    data_content = rf.read()
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-17-8cbb48f9fdb6> in <module>
#       2
#       3 with open(data_path,'r') as rf:
# ----> 4     data_content = rf.read()
#
# UnicodeDecodeError: 'cp950' codec can't decode byte 0xa2 in position 50: illegal multibyte sequence

# %%
data_object.shape
# Out:
# (39264, 27)

# %%
#how many row,column in the dataframe
row = data_object.shape[0]
col = data_object.shape[1]
print(row,col)
# Out:
# 39264 27

# %%
data_object.columns
# Out:
# Index(['run.name', 'sample.name', 'type', 'gene', 'chr', 'start', 'end',
#        'tumor purity', 'copy.number', 'copy*purity', 'LOH/HET', 'SNP#',
#        'LOH/HET count', 'SNP status', 'SNP_loc', 'p.value', 'q.values',
#        'comments', 'amplicon.total', 'amplicon.final', 'cytoband', 'role',
#        'Haplo_SI', 'BRCAness', 'ACT_pathway', 'mycancergenome_pathway',
#        'other.gene.name'],
#       dtype='object')

# %%
data_object.index
# Out:
# RangeIndex(start=0, stop=39264, step=1)

# %%
# not usion default index
data_object_1 = pd.read_excel(data_path,index_col='gene')

# %%
data_object_1.head()
# Out:
#                         run.name sample.name     type    chr     start  \
# gene
# PGAP3  Proton_B_48_IonXpress_014      B00246  Serous   chr17  37829249
# CRKL   Proton_B_48_IonXpress_014      B00246  Serous   chr22  21272220
# BUB1B  Proton_B_48_IonXpress_014      B00246  Serous   chr15  40453332
# STK11  Proton_B_48_IonXpress_014      B00246  Serous   chr19   1206845
# MEN1   Proton_B_48_IonXpress_014      B00246  Serous   chr11  64571750
#
#             end tumor purity copy.number copy*purity LOH/HET       ...        \
# gene                                                               ...
# PGAP3  37844307        30.0%           2           2     LOH       ...
# CRKL   21304221          NaN           2           2     NaN       ...
# BUB1B  40512974        30.0%         1.5         1.5     LOH       ...
# STK11   1223244        30.0%           2           2     HET       ...
# MEN1   64577547        30.0%           3           3     LOH       ...
#
# ...

# %%
data_object.columns
# Out:
# Index(['run.name', 'sample.name', 'type', 'gene', 'chr', 'start', 'end',
#        'tumor purity', 'copy.number', 'copy*purity', 'LOH/HET', 'SNP#',
#        'LOH/HET count', 'SNP status', 'SNP_loc', 'p.value', 'q.values',
#        'comments', 'amplicon.total', 'amplicon.final', 'cytoband', 'role',
#        'Haplo_SI', 'BRCAness', 'ACT_pathway', 'mycancergenome_pathway',
#        'other.gene.name'],
#       dtype='object')

# %%
data_object['sample.name'][0:5]
# Out:
# 0    B00246
# 1    B00246
# 2    B00246
# 3    B00246
# 4    B00246
# Name: sample.name, dtype: object

# %%
data_object.gene # 也可以用"." 取  但空格或"."只能用上面的方法
# Out:
# 0          PGAP3
# 1           CRKL
# 2          BUB1B
# 3          STK11
# 4           MEN1
# 5          USP9X
# 6          IL6ST
# 7           LIFR
# 8          CDC73
# 9         PIK3CA
# 10        PIK3CB
# 11        PIK3CD
# 12        PIK3CG
# 13          CRBN
# 14         FOXL2
# 15         IGF1R
# 16          TFE3
# 17         NUP98
# 18           XPC
# 19           XPA
# 20       PIK3C2B
# 21         GATA2
# 22         GATA3
# 23         GATA1
# 24         CCND1
# 25         WHSC1
# 26         CCND2
# 27         AKAP9
# 28          PTEN
# 29           MAF
#           ...
# 39234     BCL11A
# 39235     BCL11B
# 39236        VHL
# 39237       RRM1
# 39238     UGT1A1
# 39239      CMPK1
# 39240       NRAS
# 39241       MLH1
# 39242      LRP1B
# 39243    CYP2C19
# 39244       GDNF
# 39245        ICK
# 39246      PDGFB
# 39247     DNMT3A
# 39248       PIM1
# 39249      HOOK3
# 39250         AR
# 39251       NPM1
# 39252      BCL10
# 39253      PTPRT
# 39254    PLEKHG5
# ...

# %%
data_object.loc[0:10,'sample.name'] #[row,col]
# Out:
# 0     B00246
# 1     B00246
# 2     B00246
# 3     B00246
# 4     B00246
# 5     B00246
# 6     B00246
# 7     B00246
# 8     B00246
# 9     B00246
# 10    B00246
# Name: sample.name, dtype: object

# %%
data_object.loc[0:10,['sample.name','gene']]
# Out:
#    sample.name    gene
# 0       B00246   PGAP3
# 1       B00246    CRKL
# 2       B00246   BUB1B
# 3       B00246   STK11
# 4       B00246    MEN1
# 5       B00246   USP9X
# 6       B00246   IL6ST
# 7       B00246    LIFR
# 8       B00246   CDC73
# 9       B00246  PIK3CA
# 10      B00246  PIK3CB

# %%
data_object_1.index
# Out:
# Index(['PGAP3', 'CRKL', 'BUB1B', 'STK11', 'MEN1', 'USP9X', 'IL6ST', 'LIFR',
#        'CDC73', 'PIK3CA',
#        ...
#        'PLEKHG5', 'PTPRD', 'BRAF', 'GNA11', 'SDHA', 'BAP1', 'SDHB', 'ATF1',
#        'SDHD', 'PRKAR1A'],
#       dtype='object', name='gene', length=39264)

# %%
data_object_1.loc[['PIK3CA','BRAF'],['sample.name','chr']]
# Out:
#        sample.name   chr
# gene
# PIK3CA      B00246  chr3
# PIK3CA      B00432  chr3
# PIK3CA      B00266  chr3
# PIK3CA      B00290  chr3
# PIK3CA      B00303  chr3
# PIK3CA      B00263  chr3
# PIK3CA      B00290  chr3
# PIK3CA      B00283  chr3
# PIK3CA      B00257  chr3
# PIK3CA      B00268  chr3
# PIK3CA      B00420  chr3
# PIK3CA      B00270  chr3
# PIK3CA      B00239  chr3
# PIK3CA      B00302  chr3
# PIK3CA      B00431  chr3
# PIK3CA      B00269  chr3
# PIK3CA      B00281  chr3
# PIK3CA      B00286  chr3
# PIK3CA      B00426  chr3
# PIK3CA      B00267  chr3
# PIK3CA      B00298  chr3
# PIK3CA      B00439  chr3
# PIK3CA      B00278  chr3
# PIK3CA      B00263  chr3
# PIK3CA      B00255  chr3
# PIK3CA      B00430  chr3
# PIK3CA      B00437  chr3
# PIK3CA      B00299  chr3
# PIK3CA      B00245  chr3
# PIK3CA      B00261  chr3
# ...            ...   ...
# BRAF        B00284  chr7
# BRAF        B00423  chr7
# BRAF        B00242  chr7
# BRAF        B00297  chr7
# ...

# %%
data_object.loc[,]
# Out:
#   File "<ipython-input-44-4836c1fe9a44>", line 1
#     data_object.loc[,]
#                     ^
# SyntaxError: invalid syntax

# %%
data_object.loc[:,]
# Out:
#                         run.name sample.name     type     gene    chr  \
# 0      Proton_B_48_IonXpress_014      B00246  Serous     PGAP3  chr17
# 1      Proton_B_48_IonXpress_014      B00246  Serous      CRKL  chr22
# 2      Proton_B_48_IonXpress_014      B00246  Serous     BUB1B  chr15
# 3      Proton_B_48_IonXpress_014      B00246  Serous     STK11  chr19
# 4      Proton_B_48_IonXpress_014      B00246  Serous      MEN1  chr11
# 5      Proton_B_48_IonXpress_014      B00246  Serous     USP9X   chrX
# 6      Proton_B_48_IonXpress_014      B00246  Serous     IL6ST   chr5
# 7      Proton_B_48_IonXpress_014      B00246  Serous      LIFR   chr5
# 8      Proton_B_48_IonXpress_014      B00246  Serous     CDC73   chr1
# 9      Proton_B_48_IonXpress_014      B00246  Serous    PIK3CA   chr3
# 10     Proton_B_48_IonXpress_014      B00246  Serous    PIK3CB   chr3
# 11     Proton_B_48_IonXpress_014      B00246  Serous    PIK3CD   chr1
# ...

# %%
data_filter_by_gene = data_object.loc[data_object.gene == 'BRAF','type':'end'] #simple filter

# %%
data_filter_by_gene[0:10]
# Out:
#             type  gene   chr      start        end    new type
# 401      Serous   BRAF  chr7  140434389  140549943      Serous
# 810      Serous   BRAF  chr7  140434389  140549943      Serous
# 1219     Serous   BRAF  chr7  140434389  140549943      Serous
# 1628  Clear cell  BRAF  chr7  140434389  140549943  Clear cell
# 2037  Clear cell  BRAF  chr7  140434389  140549943  Clear cell
# 2446     Serous   BRAF  chr7  140434389  140549943      Serous
# 2855  Clear cell  BRAF  chr7  140434389  140549943  Clear cell
# 3264  Clear cell  BRAF  chr7  140434389  140549943  Clear cell
# 3673     Serous   BRAF  chr7  140434389  140549943      Serous
# 4082     Serous   BRAF  chr7  140434389  140549943      Serous

# %%
col = ['type','gene','role','BRCAness']

# %%
data_filter_by_gene.loc[data_filter_by_gene.type == 'Serous ',col][0:5]
# Out:
# C:\Users\yijiun0407\Anaconda3\lib\site-packages\pandas\core\indexing.py:1472: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_tuple(key)
#          type  gene  role  BRCAness
# 401   Serous   BRAF   NaN       NaN
# 810   Serous   BRAF   NaN       NaN
# 1219  Serous   BRAF   NaN       NaN
# 2446  Serous   BRAF   NaN       NaN
# 3673  Serous   BRAF   NaN       NaN

# %%
#create a new col
data_filter_by_gene['new type'] = data_filter_by_gene['type'].str.strip()

# %%
data_filter_by_gene[0:5]
# Out:
#             type  gene   chr      start        end    new type
# 401      Serous   BRAF  chr7  140434389  140549943      Serous
# 810      Serous   BRAF  chr7  140434389  140549943      Serous
# 1219     Serous   BRAF  chr7  140434389  140549943      Serous
# 1628  Clear cell  BRAF  chr7  140434389  140549943  Clear cell
# 2037  Clear cell  BRAF  chr7  140434389  140549943  Clear cell

# %%
data_filter_by_gene.loc[data_filter_by_gene['new type'] == 'Serous',]
# Out:
#           type  gene   chr      start        end new type
# 401    Serous   BRAF  chr7  140434389  140549943   Serous
# 810    Serous   BRAF  chr7  140434389  140549943   Serous
# 1219   Serous   BRAF  chr7  140434389  140549943   Serous
# 2446   Serous   BRAF  chr7  140434389  140549943   Serous
# 3673   Serous   BRAF  chr7  140434389  140549943   Serous
# 4082   Serous   BRAF  chr7  140434389  140549943   Serous
# 4900   Serous   BRAF  chr7  140434389  140549943   Serous
# 5309   Serous   BRAF  chr7  140434389  140549943   Serous
# 6536   Serous   BRAF  chr7  140434389  140549943   Serous
# 8172   Serous   BRAF  chr7  140434389  140549943   Serous
# 8990   Serous   BRAF  chr7  140434389  140549943   Serous
# 9808   Serous   BRAF  chr7  140434389  140549943   Serous
# 10217  Serous   BRAF  chr7  140434389  140549943   Serous
# 11853  Serous   BRAF  chr7  140434389  140549943   Serous
# 12262  Serous   BRAF  chr7  140434389  140549943   Serous
# ...

# %%
data_object.dtypes
# Out:
# run.name                   object
# sample.name                object
# type                       object
# gene                       object
# chr                        object
# start                      object
# end                        object
# tumor purity               object
# copy.number                object
# copy*purity                object
# LOH/HET                    object
# SNP#                      float64
# LOH/HET count              object
# SNP status                 object
# SNP_loc                    object
# p.value                    object
# q.values                   object
# comments                   object
# amplicon.total              int64
# amplicon.final              int64
# cytoband                   object
# role                       object
# Haplo_SI                   object
# BRCAness                   object
# ACT_pathway                object
# mycancergenome_pathway     object
# other.gene.name            object
# dtype: object

# %%
data_object.loc[data_object['amplicon.total'] > 30,col].head()
# Out:
#       type    gene      role BRCAness
# 2  Serous    BUB1B         .        .
# 5  Serous    USP9X         .        .
# 6  Serous    IL6ST         .        .
# 7  Serous     LIFR         .        .
# 9  Serous   PIK3CA  oncogene        .

# %%
data_object.sort_values(['amplicon.total','sample.name'],ascending = False)
# Out:
#                          run.name sample.name          type   gene   chr  \
# 15913   Proton_B_72_IonXpress_090      B00446  endometrioid  SYNE1  chr6
# 16731   Proton_B_72_IonXpress_089      B00445  endometrioid  SYNE1  chr6
# 23275  Proton_B_123_IonXpress_038      B00444  endometrioid  SYNE1  chr6
# 25729  Proton_B_130_IonXpress_038      B00444  endometrioid  SYNE1  chr6
# 13050  Proton_B_122_IonXpress_037      B00443  endometrioid  SYNE1  chr6
# 33909  Proton_B_122_IonXpress_036      B00442  endometrioid  SYNE1  chr6
# 32273  Proton_B_122_IonXpress_035      B00441  endometrioid  SYNE1  chr6
# 37590  Proton_B_122_IonXpress_034      B00440  endometrioid  SYNE1  chr6
# 8960   Proton_B_121_IonXpress_033      B00439       Serous   SYNE1  chr6
# 11005  Proton_B_121_IonXpress_032      B00437  endometrioid  SYNE1  chr6
# 36363   Proton_B_88_IonXpress_082      B00435  endometrioid  SYNE1  chr6
# 30228   Proton_B_85_IonXpress_081      B00434  endometrioid  SYNE1  chr6
# ...

# %%
data_object.head()
# Out:
#                     run.name sample.name     type   gene    chr     start  \
# 0  Proton_B_48_IonXpress_014      B00246  Serous   PGAP3  chr17  37829249
# 1  Proton_B_48_IonXpress_014      B00246  Serous    CRKL  chr22  21272220
# 2  Proton_B_48_IonXpress_014      B00246  Serous   BUB1B  chr15  40453332
# 3  Proton_B_48_IonXpress_014      B00246  Serous   STK11  chr19   1206845
# 4  Proton_B_48_IonXpress_014      B00246  Serous    MEN1  chr11  64571750
#
#         end tumor purity copy.number copy*purity       ...         \
# 0  37844307        30.0%           2           2       ...
# 1  21304221          NaN           2           2       ...
# 2  40512974        30.0%         1.5         1.5       ...
# 3   1223244        30.0%           2           2       ...
# 4  64577547        30.0%           3           3       ...
#
#                                 comments  amplicon.total amplicon.final  \
# 0    p-value_correction=0.64177792041869              15             12
# ...

# %%
data_object['tumor purity'].fillna(0) #fill na
# Out:
# 0                 30.0%
# 1                     0
# 2                 30.0%
# 3                 30.0%
# 4                 30.0%
# 5                 30.0%
# 6                 30.0%
# 7                 30.0%
# 8                     0
# 9                     0
# 10                    0
# 11                    0
# 12                30.0%
# 13                30.0%
# 14                    0
# 15                30.0%
# 16                    0
# 17                30.0%
# 18                30.0%
# 19                    0
# 20                30.0%
# 21                30.0%
# 22                    0
# 23                    0
# 24                30.0%
# 25                    0
# 26                    0
# 27                    0
# 28                    0
# 29                    0
#               ...
# 39234                 0
# 39235    66.3812742265%
# 39236                 0
# 39237    66.3812742265%
# 39238                 0
# 39239                 0
# 39240                 0
# ...

# %%
data_object['concate'] = data_object['sample.name'] +'_'+data_object['type']+'_'+data_object['gene']

# %%
data_object.head()
# Out:
#                     run.name sample.name     type   gene    chr     start  \
# 0  Proton_B_48_IonXpress_014      B00246  Serous   PGAP3  chr17  37829249
# 1  Proton_B_48_IonXpress_014      B00246  Serous    CRKL  chr22  21272220
# 2  Proton_B_48_IonXpress_014      B00246  Serous   BUB1B  chr15  40453332
# 3  Proton_B_48_IonXpress_014      B00246  Serous   STK11  chr19   1206845
# 4  Proton_B_48_IonXpress_014      B00246  Serous    MEN1  chr11  64571750
#
#         end tumor purity copy.number copy*purity          ...           \
# 0  37844307        30.0%           2           2          ...
# 1  21304221          NaN           2           2          ...
# 2  40512974        30.0%         1.5         1.5          ...
# 3   1223244        30.0%           2           2          ...
# 4  64577547        30.0%           3           3          ...
#
#   amplicon.total  amplicon.final  cytoband role Haplo_SI BRCAness  \
# 0             15              12     17q12    .        .        .
# ...

# %%
data_object['machine'] = data_object['run.name'].str.split('_').str[0:3].str.join('_')

# %%
data_object.head()
# Out:
#                     run.name sample.name     type   gene    chr     start  \
# 0  Proton_B_48_IonXpress_014      B00246  Serous   PGAP3  chr17  37829249
# 1  Proton_B_48_IonXpress_014      B00246  Serous    CRKL  chr22  21272220
# 2  Proton_B_48_IonXpress_014      B00246  Serous   BUB1B  chr15  40453332
# 3  Proton_B_48_IonXpress_014      B00246  Serous   STK11  chr19   1206845
# 4  Proton_B_48_IonXpress_014      B00246  Serous    MEN1  chr11  64571750
#
#         end tumor purity copy.number copy*purity     ...      amplicon.final  \
# 0  37844307        30.0%           2           2     ...                  12
# 1  21304221          NaN           2           2     ...                  10
# 2  40512974        30.0%         1.5         1.5     ...                  44
# 3   1223244        30.0%           2           2     ...                  15
# 4  64577547        30.0%           3           3     ...                  18
#
# ...

# %%
type(data_object['run.name']) # Series
# Out:
# pandas.core.series.Series

# %%
data_object['run.name'].tolist() # Series To list
# Out:
# ['Proton_B_48_IonXpress_014',
#  'Proton_B_48_IonXpress_014',
#  'Proton_B_48_IonXpress_014',
#  'Proton_B_48_IonXpress_014',
#  'Proton_B_48_IonXpress_014',
#  'Proton_B_48_IonXpress_014',
#  'Proton_B_48_IonXpress_014',
#  'Proton_B_48_IonXpress_014',
#  'Proton_B_48_IonXpress_014',
#  'Proton_B_48_IonXpress_014',
#  'Proton_B_48_IonXpress_014',
#  'Proton_B_48_IonXpress_014',
#  'Proton_B_48_IonXpress_014',
#  'Proton_B_48_IonXpress_014',
#  'Proton_B_48_IonXpress_014',
#  'Proton_B_48_IonXpress_014',
#  'Proton_B_48_IonXpress_014',
#  'Proton_B_48_IonXpress_014',
#  'Proton_B_48_IonXpress_014',
#  'Proton_B_48_IonXpress_014',
#  'Proton_B_48_IonXpress_014',
#  'Proton_B_48_IonXpress_014',
#  'Proton_B_48_IonXpress_014',
#  'Proton_B_48_IonXpress_014',
#  'Proton_B_48_IonXpress_014',
#  'Proton_B_48_IonXpress_014',
#  'Proton_B_48_IonXpress_014',
#  'Proton_B_48_IonXpress_014',
#  'Proton_B_48_IonXpress_014',
#  'Proton_B_48_IonXpress_014',
#  'Proton_B_48_IonXpress_014',
# ...
