# %%
! pip install mysql
# Out:
# ...
#   Running setup.py bdist_wheel for mysql: started
#   Running setup.py bdist_wheel for mysql: finished with status 'done'
#   Stored in directory: C:\Users\bonniechen\AppData\Local\pip\Cache\wheels\4f\10\3f\4930effd0320769375b5094e279cb0e4a4c10a7e5811b58f8a
# Successfully built mysql
# ...

# %%
# !python --version
# Out:
# Python 3.7.1

# %%
import MySQLdb
import pandas as pd
from sqlalchemy import create_engine

# %%
db = MySQLdb.connect(host = '192.168.5.104', port = 3307, user = 'root', passwd = 'root', db = 'demo_db')

# %%
# create the query
query1 = "select * from allCuratedGenes"
query2 = "select * from allAnnotatedVariants"

# %%
df_query1 = pd.read_sql(query1, con=db)
df_query2 = pd.read_sql(query2, con=db)

# %%
df_query1
# Out:
#              Isoform          RefSeq  Entrez Gene ID Hugo Symbol Is Oncogene  \
# 0    ENST00000318560     NM_005157.4              25        ABL1         Yes
# 1    ENST00000502732     NM_007314.3              27        ABL2         Yes
# 2    ENST00000331925  NM_001199954.1              71       ACTG1          No
# 3    ENST00000263640  NM_001111067.2              90       ACVR1         Yes
# 4    ENST00000220592     NM_012154.3           27161        AGO2          No
# 5    ENST00000349310  NM_001014431.1             207        AKT1         Yes
# 6    ENST00000392038     NM_001626.4             208        AKT2         Yes
# 7    ENST00000263826     NM_005465.4           10000        AKT3         Yes
# 8    ENST00000389048     NM_004304.4             238         ALK         Yes
# 9    ENST00000319144     NM_001139.2             242     ALOX12B          No
# 10   ENST00000330258     NM_152424.3          139285       AMER1          No
# ...

# %%
conn_string = "mysql://root:root@192.168.5.104:3307/demo_db"

# %%
sql_engine = create_engine(conn_string)

# %%
sql_engine
# Out:
# Engine(mysql://root:***@192.168.5.104:3307/demo_db)
