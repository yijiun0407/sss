# %%
from bs4 import BeautifulSoup as bs
import urllib3 as url

# %%
http = url.PoolManager()
r = http.request('GET','https://blog.gtwang.org/programming/python-beautiful-soup-module-scrape-web-pages-tutorial/3/')
# Out:
# C:\Users\yijiun0407\Anaconda3\lib\site-packages\urllib3\connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)

# %%
r

# %%
type(r)
# Out:
# urllib3.response.HTTPResponse

# %%
r.data
# Out:
# b'<!DOCTYPE html>\r\n<html class="no-js" lang="zh-TW">\r\n\t<head profile="http://gmpg.org/xfn/11">\r\n\t\t<meta http-equiv="Content-Type" content="text/html; charset=UTF-8" />\r\n\t\t<meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=1.0" >\r\n\t\t<title>Python \xe4\xbd\xbf\xe7\x94\xa8 Beautiful Soup \xe6\x8a\x93\xe5\x8f\x96\xe8\x88\x87\xe8\xa7\xa3\xe6\x9e\x90\xe7\xb6\xb2\xe9\xa0\x81\xe8\xb3\x87\xe6\x96\x99\xef\xbc\x8c\xe9\x96\x8b\xe7\x99\xbc\xe7\xb6\xb2\xe8\xb7\xaf\xe7\x88\xac\xe8\x9f\xb2\xe6\x95\x99\xe5\xad\xb8 - \xe9\xa0\x813\xef\xbc\x8c\xe5\x85\xb13 - G. T. Wang</title>\n<script>document.documentElement.className = document.documentElement.className.replace("no-js","js");</script>\n\n<!-- This site is optimized with the Yoast SEO plugin v12.0 - https://yoast.com/wordpress/plugins/seo/ -->\n<link rel="canonical" href="https://blog.gtwang.org/programming/python-beautiful-soup-module-scrape-web-pages-tutorial/3/" />\n<link rel="prev" href="https://b
# ...

# %%
soup = bs(r.data,'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html class="no-js" lang="zh-TW">
# <head profile="http://gmpg.org/xfn/11">
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0" name="viewport"/>
# <title>Python 使用 Beautiful Soup 抓取與解析網頁資料，開發網路爬蟲教學 - 頁3，共3 - G. T. Wang</title>
# <script>document.documentElement.className = document.documentElement.className.replace("no-js","js");</script>
# <!-- This site is optimized with the Yoast SEO plugin v12.0 - https://yoast.com/wordpress/plugins/seo/ -->
# <link href="https://blog.gtwang.org/programming/python-beautiful-soup-module-scrape-web-pages-tutorial/3/" rel="canonical"/>
# <link href="https://blog.gtwang.org/programming/python-beautiful-soup-module-scrape-web-pages-tutorial/2/" rel="prev"/>
# <meta content="zh_TW" property="og:locale">
# <meta content="article" property="og:type"/>
# ...

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="no-js" lang="zh-TW">
#  <head profile="http://gmpg.org/xfn/11">
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0" name="viewport"/>
#   <title>
#    Python 使用 Beautiful Soup 抓取與解析網頁資料，開發網路爬蟲教學 - 頁3，共3 - G. T. Wang
#   </title>
#   <script>
#    document.documentElement.className = document.documentElement.className.replace("no-js","js");
#   </script>
#   <!-- This site is optimized with the Yoast SEO plugin v12.0 - https://yoast.com/wordpress/plugins/seo/ -->
#   <link href="https://blog.gtwang.org/programming/python-beautiful-soup-module-scrape-web-pages-tutorial/3/" rel="canonical"/>
#   <link href="https://blog.gtwang.org/programming/python-beautiful-soup-module-scrape-web-pages-tutorial/2/" rel="prev"/>
#   <meta content="zh_TW" property="og:locale">
#    <meta content="article" property="og:type"/>
# ...

# %%
soup.title
# Out:
# <title>Python 使用 Beautiful Soup 抓取與解析網頁資料，開發網路爬蟲教學 - 頁3，共3 - G. T. Wang</title>

# %%
title = soup.title.string

# %%
title
# Out:
# 'Python 使用 Beautiful Soup 抓取與解析網頁資料，開發網路爬蟲教學 - 頁3，共3 - G. T. Wang'

# %%
meta_tags = soup.find_all('a')

# %%
len(meta_tags)
# Out:
# 86

# %%
for _ in meta_tags :
    print(_.string)
# Out:
# Blogger 舊站
# 關於
# Facebook
# Flickr
# None
# 物聯網
# 網站架設
# 程式設計
# 統計
# 素食
# 特價優惠
# 宗教
# 物聯網
# 網站架設
# 程式設計
# 統計
# 素食
# 特價優惠
# 宗教
# Python 使用 Beautiful Soup 抓取與解析網頁資料，開發網路爬蟲教學
# None
# None
# None
# None
# None
# None
# DigitalOcean
# DigitalOcean
# opensource.com
# 1
# 2
# 程式設計
# Python
# 網路
# None
# G. T. Wang
# None
# Add Comment →
# 2019/03/26
# Reply
# 2019/05/06
# Reply
# 2019/08/09
# Reply
# 從範例學程式進階 – Python(1080808-09) | 碧華國小資訊中心
# 取消回覆
# Coursera 線上教學課程
# Udemy 線上教學課程
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# 如何戒邪淫、遠離婚外情
# 戒淫寶典：《壽康寶鑑》白話有聲書
# 智邦公益網
# 台灣世界展望會
# igiving 公益網
# 家扶基金會
# Yahoo 奇摩公益
# G. T. Wang

# %%
for _ in meta_tags :
    print(_['href'])
# Out:
# http://blogger.gtwang.org/
# https://blog.gtwang.org/about/
# https://www.facebook.com/GTWang.org/
# https://www.flickr.com/photos/gtwang/
# https://blog.gtwang.org/
# https://blog.gtwang.org/category/iot/
# https://blog.gtwang.org/web-building/
# https://blog.gtwang.org/programming/
# https://blog.gtwang.org/statistics/
# https://blog.gtwang.org/tag/vegetarian/
# https://blog.gtwang.org/tag/sale/
# https://blog.gtwang.org/religion/
# https://blog.gtwang.org/category/iot/
# https://blog.gtwang.org/web-building/
# https://blog.gtwang.org/programming/
# https://blog.gtwang.org/statistics/
# https://blog.gtwang.org/tag/vegetarian/
# https://blog.gtwang.org/tag/sale/
# https://blog.gtwang.org/religion/
# https://blog.gtwang.org/programming/python-beautiful-soup-module-scrape-web-pages-tutorial/
# https://blog.gtwang.org/programming/python-beautiful-soup-module-scrape-web-pages-tutorial/#comments
# ...

# %%
for _ in div_tags:
    print(_.string)
# Out:
# None
